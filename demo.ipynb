# %% [markdown]
# # ASR Conformer-CTC Demo
# Этот ноутбук демонстрирует работу модели распознавания речи, реализованной в рамках проекта.

# %%
# @title 1. Клонирование и установка
# !git clone https://github.com/dgokr2-wq/ASR_Conformer_Project.git
# %cd ASR_Conformer_Project
# !pip install -r requirements.txt
# !pip install gdown

# %%
# @title 2. Загрузка весов модели
import gdown
# ЗАМЕНИ 'ID_FILE' на реальный ID твоего файла с Google Drive
file_id = 'ID_ТВОЕГО_ФАЙЛА_ЗДЕСЬ'
url = f'https://drive.google.com/uc?id={file_id}'
gdown.download(url, 'final_model.pth', quiet=False)

# %%
# @title 3. Запуск инференса
import torch
import os

os.makedirs('test_audio', exist_ok=True)
os.makedirs('results', exist_ok=True)

# Скачиваем тестовый пример
# !wget https://www.voiptroubleshooter.com/open_speech/american/phrase_1.wav -O test_audio/sample.wav

# Запуск скрипта
# !python3 inference.py --input_dir ./test_audio --output_dir ./results

print('\n--- РЕЗУЛЬТАТ ---')
with open('results/sample.txt', 'r') as f:
    print(f.read())
